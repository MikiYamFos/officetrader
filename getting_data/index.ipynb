# %%
import pandas as pd

# %%
dfs = pd.read_html('./cruz-source.html')

# %%
# dfs[0]

# %%
df = pd.read_html('./selected.html')[0]

# %%
some_html = ' '.join([str(val) for val in list(df[1].values)])

# %%
with open('readme.txt', 'w') as f:
    f.write(some_html)

# %%
import pandas as pd
dfs = pd.read_html('readme.html')

# %%
dfs[1].to_dict('records')
# Out:
# [{'Unnamed: 0': 1.0,
#   'Asset': 'GGLPX - Goldman Sachs High Yield Municipal Fund Class PFiler comment: In calendar year 2017 I owned GHYIX. Due to Goldman Sachs share class conversion during calendar year 2018 the ticker symbol has changed from GHYIX to GGLPX.',
#   'Asset Type': 'Mutual FundsMutual Fund',
#   'Owner': 'Joint',
#   'Value': '$1,001 - $15,000',
#   'Income Type': 'Dividends, Excepted Investment Fund,',
#   'Income': '$201 - $1,000'},
#  {'Unnamed: 0': 2.0,
#   'Asset': 'GMWPX - Goldman Sachs Local Emerging Markets Debt Fund ClaFiler comment: In calendar year 2017 I owned GIMDX. Due to Goldman Sachs share class conversion during calendar year 2018 the ticker symbol has changed from GIMDX to GMWPX',
#   'Asset Type': 'Mutual FundsMutual Fund',
#   'Owner': 'Joint',
#   'Value': '$1,001 - $15,000',
#   'Income Type': 'Dividends, Excepted Investment Fund,',
#   'Income': '$201 - $1,000'},
#  {'Unnamed: 0': 3.0,
# ...
